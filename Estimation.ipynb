# %%
# %load_ext autoreload
# %autoreload 2
import models
import orca

# %%
# %%capture
orca.run(["build_networks", "neighborhood_vars"])

# %% [markdown]
# ## Residential Price Hedonice Estimation

# %%
orca.run(["rsh_estimate"])
# Out:
# Running step 'rsh_estimate'
# REGRESSION RESULTS FOR SEGMENT 19
#
#                                  OLS Regression Results
# ========================================================================================
# Dep. Variable:     np.log1p(res_price_per_sqft)   R-squared:                       0.235
# Model:                                      OLS   Adj. R-squared:                  0.234
# Method:                           Least Squares   F-statistic:                     824.2
# Date:                          Fri, 20 Nov 2015   Prob (F-statistic):               0.00
# Time:                                  20:28:01   Log-Likelihood:                -52275.
# No. Observations:                         45749   AIC:                         1.046e+05
# Df Residuals:                             45731   BIC:                         1.047e+05
# Df Model:                                    17
# Covariance Type:                      nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------------------------------
# Intercept                               -58.9924      1.796    -32.839      0.000       -62.513   -55.471
# I(year_built < 1940)[T.True]              0.8174      0.040     20.227      0.000         0.738     0.897
# I(distance_to_coast < 10000)[T.True]      0.3162      0.018     17.168      0.000         0.280     0.352
# I(distance_to_park < 400)[T.True]        -0.0009      0.016     -0.055      0.956        -0.032     0.030
# I(distance_to_school < 800)[T.True]       0.0926      0.013      7.248      0.000         0.068     0.118
# I(distance_to_freeway < 400)[T.True]     -0.0072      0.025     -0.284      0.776        -0.057     0.043
# year_built_1940to1950[T.True]             0.6134      0.032     19.045      0.000         0.550     0.677
# year_built_1950to1960[T.True]             0.5046      0.024     21.036      0.000         0.458     0.552
# year_built_1960to1970[T.True]             0.2723      0.020     13.379      0.000         0.232     0.312
# year_built_1970to1980[T.True]             0.1938      0.015     12.876      0.000         0.164     0.223
# I(ave_age_of_head_1500m < 35)[T.True]   -58.9924      1.796    -32.839      0.000       -62.513   -55.471
# ave_income                                0.2551      0.011     23.454      0.000         0.234     0.276
# jobs_400m                                -0.1102      0.003    -40.099      0.000        -0.116    -0.105
# res_occupancy_3000m                       3.1667      0.050     63.132      0.000         3.068     3.265
# np.log1p(distance_to_coast)              -0.1273      0.007    -18.515      0.000        -0.141    -0.114
# residential_units_1500m                3.248e-05   2.43e-06     13.392      0.000      2.77e-05  3.72e-05
# ave_children_1500m                       -0.6362      0.015    -42.201      0.000        -0.666    -0.607
# year_built                                0.0038      0.001      7.227      0.000         0.003     0.005
# ave_year_built_1500m                     14.6792      0.489     29.995      0.000        13.720    15.638
# ==============================================================================
# Omnibus:                    24775.003   Durbin-Watson:                   0.633
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           310139.882
# Skew:                          -2.344   Prob(JB):                         0.00
# Kurtosis:                      14.863   Cond. No.                     2.35e+19
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.81e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# REGRESSION RESULTS FOR SEGMENT 20
#
#                                  OLS Regression Results
# ========================================================================================
# Dep. Variable:     np.log1p(res_price_per_sqft)   R-squared:                       0.254
# Model:                                      OLS   Adj. R-squared:                  0.252
# Method:                           Least Squares   F-statistic:                     118.7
# Date:                          Fri, 20 Nov 2015   Prob (F-statistic):               0.00
# Time:                                  20:28:01   Log-Likelihood:                -11740.
# No. Observations:                          6980   AIC:                         2.352e+04
# Df Residuals:                              6959   BIC:                         2.367e+04
# Df Model:                                    20
# Covariance Type:                      nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------------------------------
# Intercept                               -80.0659     30.890     -2.592      0.010      -140.620   -19.512
# I(year_built < 1940)[T.True]              0.9892      0.304      3.251      0.001         0.393     1.586
# I(distance_to_coast < 10000)[T.True]      0.2009      0.063      3.215      0.001         0.078     0.323
# I(distance_to_park < 400)[T.True]         0.2742      0.064      4.312      0.000         0.150     0.399
# I(distance_to_school < 800)[T.True]       0.0451      0.051      0.888      0.374        -0.054     0.145
# year_built_1940to1950[T.True]             1.1169      0.237      4.708      0.000         0.652     1.582
# year_built_1950to1960[T.True]             1.0439      0.193      5.398      0.000         0.665     1.423
# year_built_1960to1970[T.True]             0.8076      0.163      4.941      0.000         0.487     1.128
# year_built_1970to1980[T.True]             0.4382      0.112      3.908      0.000         0.218     0.658
# year_built_1980to1990[T.True]             0.2070      0.078      2.670      0.008         0.055     0.359
# I(ave_age_of_head_1500m < 35)[T.True]   -80.0659     30.890     -2.592      0.010      -140.620   -19.512
# I(distance_to_freeway < 800)[T.True]     -0.3133      0.065     -4.795      0.000        -0.441    -0.185
# ave_income                               -0.1111      0.075     -1.476      0.140        -0.259     0.036
# jobs_400m                                -0.1170      0.010    -11.745      0.000        -0.137    -0.098
# res_occupancy_3000m                       3.0898      0.238     12.955      0.000         2.622     3.557
# np.log1p(distance_to_coast)              -0.3534      0.025    -14.403      0.000        -0.401    -0.305
# residential_units_1500m                8.851e-05   7.84e-06     11.287      0.000      7.31e-05     0.000
# ave_children_1500m                        0.0125      0.071      0.176      0.860        -0.127     0.152
# np.log1p(year_built)                     10.8222      7.866      1.376      0.169        -4.597    26.241
# ave_year_built_1500m                     11.4185      1.219      9.367      0.000         9.029    13.808
# np.log1p(distance_to_onramp)             -0.1126      0.021     -5.291      0.000        -0.154    -0.071
# np.log1p(distance_to_transit)            -0.2268      0.029     -7.874      0.000        -0.283    -0.170
# ==============================================================================
# Omnibus:                      428.304   Durbin-Watson:                   0.721
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              511.418
# Skew:                          -0.663   Prob(JB):                    8.85e-112
# Kurtosis:                       2.955   Cond. No.                     3.36e+19
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.12e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# REGRESSION RESULTS FOR SEGMENT 21
#
#                                  OLS Regression Results
# ========================================================================================
# Dep. Variable:     np.log1p(res_price_per_sqft)   R-squared:                       0.262
# Model:                                      OLS   Adj. R-squared:                  0.260
# Method:                           Least Squares   F-statistic:                     163.0
# Date:                          Fri, 20 Nov 2015   Prob (F-statistic):               0.00
# Time:                                  20:28:01   Log-Likelihood:                -11443.
# No. Observations:                          6443   AIC:                         2.292e+04
# Df Residuals:                              6428   BIC:                         2.302e+04
# Df Model:                                    14
# Covariance Type:                      nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------------------------------
# Intercept                              -175.6543     13.814    -12.716      0.000      -202.734  -148.575
# I(year_built < 1940)[T.True]              3.0768      0.194     15.886      0.000         2.697     3.457
# I(distance_to_school < 800)[T.True]      -0.4530      0.078     -5.789      0.000        -0.606    -0.300
# year_built_1940to1950[T.True]             3.1966      0.216     14.807      0.000         2.773     3.620
# year_built_1950to1960[T.True]             2.0664      0.131     15.816      0.000         1.810     2.323
# year_built_1960to1970[T.True]             1.6883      0.087     19.399      0.000         1.518     1.859
# I(ave_age_of_head_1500m < 35)[T.True]  -175.6543     13.814    -12.716      0.000      -202.734  -148.575
# ave_income                                0.4125      0.084      4.904      0.000         0.248     0.577
# jobs_3000m                            -3.174e-05   2.76e-06    -11.484      0.000     -3.72e-05 -2.63e-05
# res_occupancy_3000m                       1.0436      0.155      6.730      0.000         0.740     1.348
# residential_units_1500m                7.942e-05    6.4e-06     12.402      0.000      6.69e-05   9.2e-05
# np.log1p(year_built)                     47.0256      3.649     12.887      0.000        39.872    54.179
# np.log1p(distance_to_onramp)             -0.1045      0.019     -5.438      0.000        -0.142    -0.067
# np.log1p(distance_to_transit)            -0.3056      0.028    -10.881      0.000        -0.361    -0.251
# np.log1p(distance_to_school)             -0.3153      0.047     -6.744      0.000        -0.407    -0.224
# np.log1p(distance_to_coast)              -0.2964      0.014    -21.052      0.000        -0.324    -0.269
# ==============================================================================
# Omnibus:                      354.500   Durbin-Watson:                   0.854
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              436.822
# Skew:                           0.556   Prob(JB):                     1.40e-95
# Kurtosis:                       3.624   Cond. No.                     6.09e+20
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.68e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Time to execute step 'rsh_estimate': 3.23 s
# Total time to execute iteration 1 with iteration value None: 3.23 s

# %%
orca.run(["rsh_simulate"])
# Out:
# Running step 'rsh_simulate'
# count    632386.000000
# mean        193.134270
# std          95.758474
# min           0.644238
# 25%         139.872706
# 50%         187.588360
# 75%         232.267315
# max        1160.735870
# dtype: float64
# Time to execute step 'rsh_simulate': 6.74 s
# Total time to execute iteration 1 with iteration value None: 6.74 s

# %% [markdown]
# ## Non-residential Rent Hedonic Estimation

# %%
orca.run(["nrh_estimate"])
# Out:
# Running step 'nrh_estimate'
# REGRESSION RESULTS FOR SEGMENT 2
#
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     np.log1p(nonres_rent_per_sqft)   R-squared:                       0.209
# Model:                                        OLS   Adj. R-squared:                  0.206
# Method:                             Least Squares   F-statistic:                     59.92
# Date:                            Fri, 20 Nov 2015   Prob (F-statistic):           5.13e-87
# Time:                                    20:28:09   Log-Likelihood:                -252.91
# No. Observations:                            1822   AIC:                             523.8
# Df Residuals:                                1813   BIC:                             573.4
# Df Model:                                       8
# Covariance Type:                        nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------------
# Intercept                       -0.9928      1.416     -0.701      0.483        -3.769     1.784
# I(year_built < 1940)[T.True]     0.6949      0.283      2.457      0.014         0.140     1.250
# I(year_built > 2005)[T.True]     0.1222      0.031      3.975      0.000         0.062     0.183
# np.log1p(stories)                0.4203      0.041     10.147      0.000         0.339     0.501
# jobs_400m                        0.0244      0.007      3.556      0.000         0.011     0.038
# year_built                       0.0016      0.001      2.187      0.029         0.000     0.003
# distance_to_coast            -5.062e-06   4.42e-07    -11.448      0.000     -5.93e-06 -4.19e-06
# distance_to_freeway          -1.279e-05   1.85e-06     -6.924      0.000     -1.64e-05 -9.17e-06
# nonres_occupancy_3000m           0.2566      0.033      7.712      0.000         0.191     0.322
# ==============================================================================
# Omnibus:                      412.679   Durbin-Watson:                   1.165
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1943.590
# Skew:                           0.996   Prob(JB):                         0.00
# Kurtosis:                       7.651   Cond. No.                     7.24e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.24e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# REGRESSION RESULTS FOR SEGMENT 4
#
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     np.log1p(nonres_rent_per_sqft)   R-squared:                       0.222
# Model:                                        OLS   Adj. R-squared:                  0.215
# Method:                             Least Squares   F-statistic:                     36.60
# Date:                            Fri, 20 Nov 2015   Prob (F-statistic):           2.84e-51
# Time:                                    20:28:09   Log-Likelihood:                -246.51
# No. Observations:                            1038   AIC:                             511.0
# Df Residuals:                                1029   BIC:                             555.5
# Df Model:                                       8
# Covariance Type:                        nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------------
# Intercept                      -12.5714      1.773     -7.090      0.000       -16.051    -9.092
# I(year_built < 1940)[T.True]     0.1954      0.137      1.431      0.153        -0.072     0.463
# I(year_built > 2005)[T.True]     0.1205      0.049      2.462      0.014         0.024     0.217
# np.log1p(stories)                0.0991      0.023      4.337      0.000         0.054     0.144
# ave_income                       0.0071      0.003      2.072      0.039         0.000     0.014
# jobs_400m                        0.0108      0.009      1.258      0.209        -0.006     0.028
# year_built                       0.0078      0.001      8.753      0.000         0.006     0.010
# distance_to_coast            -5.999e-06   6.02e-07     -9.972      0.000     -7.18e-06 -4.82e-06
# nonres_occupancy_3000m           0.0099      0.052      0.190      0.850        -0.092     0.112
# ==============================================================================
# Omnibus:                       40.370   Durbin-Watson:                   1.400
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               81.908
# Skew:                          -0.241   Prob(JB):                     1.64e-18
# Kurtosis:                       4.289   Cond. No.                     5.17e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.17e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# REGRESSION RESULTS FOR SEGMENT 5
#
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     np.log1p(nonres_rent_per_sqft)   R-squared:                       0.160
# Model:                                        OLS   Adj. R-squared:                  0.156
# Method:                             Least Squares   F-statistic:                     36.78
# Date:                            Fri, 20 Nov 2015   Prob (F-statistic):           2.52e-47
# Time:                                    20:28:09   Log-Likelihood:                -544.84
# No. Observations:                            1359   AIC:                             1106.
# Df Residuals:                                1351   BIC:                             1147.
# Df Model:                                       7
# Covariance Type:                        nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------------
# Intercept                       -4.5473      1.485     -3.063      0.002        -7.460    -1.635
# I(year_built < 1940)[T.True]     0.1383      0.071      1.938      0.053        -0.002     0.278
# I(year_built > 2005)[T.True]     0.2089      0.065      3.231      0.001         0.082     0.336
# ave_income                       0.0522      0.006      8.240      0.000         0.040     0.065
# jobs_1500m                       0.0394      0.010      3.898      0.000         0.020     0.059
# year_built                       0.0034      0.001      4.555      0.000         0.002     0.005
# distance_to_coast            -5.444e-06   5.79e-07     -9.399      0.000     -6.58e-06 -4.31e-06
# nonres_occupancy_3000m           0.2314      0.054      4.291      0.000         0.126     0.337
# ==============================================================================
# Omnibus:                        9.841   Durbin-Watson:                   1.190
# Prob(Omnibus):                  0.007   Jarque-Bera (JB):               10.522
# Skew:                          -0.158   Prob(JB):                      0.00519
# Kurtosis:                       3.293   Cond. No.                     4.90e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.9e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Time to execute step 'nrh_estimate': 1.56 s
# Total time to execute iteration 1 with iteration value None: 1.56 s

# %%
orca.run(["nrh_simulate"])
# Out:
# Running step 'nrh_simulate'
# count    27077.000000
# mean        17.592813
# std          4.905132
# min          1.208648
# 25%         12.805182
# 50%         18.226083
# 75%         21.316938
# max         35.735924
# dtype: float64
# Time to execute step 'nrh_simulate': 3.64 s
# Total time to execute iteration 1 with iteration value None: 3.65 s

# %%
orca.run(["nrh_estimate2"])
# Out:
# Running step 'nrh_estimate2'
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     np.log1p(nonres_rent_per_sqft)   R-squared:                       0.183
# Model:                                        OLS   Adj. R-squared:                  0.181
# Method:                             Least Squares   F-statistic:                     104.8
# Date:                            Fri, 20 Nov 2015   Prob (F-statistic):          1.82e-177
# Time:                                    20:28:14   Log-Likelihood:                -2103.1
# No. Observations:                            4219   AIC:                             4226.
# Df Residuals:                                4209   BIC:                             4290.
# Df Model:                                       9
# Covariance Type:                        nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------------
# Intercept                        0.2138      1.086      0.197      0.844        -1.914     2.342
# I(year_built < 1940)[T.True]     0.1722      0.066      2.594      0.010         0.042     0.302
# I(year_built > 2005)[T.True]     0.0960      0.031      3.059      0.002         0.034     0.158
# np.log1p(stories)                0.3255      0.021     15.408      0.000         0.284     0.367
# ave_income                       0.0186      0.002     10.077      0.000         0.015     0.022
# jobs_400m                        0.0123      0.006      2.094      0.036         0.001     0.024
# year_built                       0.0011      0.001      2.060      0.039      5.44e-05     0.002
# distance_to_coast            -6.259e-06   3.83e-07    -16.350      0.000     -7.01e-06 -5.51e-06
# distance_to_freeway          -8.125e-06   1.74e-06     -4.669      0.000     -1.15e-05 -4.71e-06
# nonres_occupancy_3000m           0.0092      0.032      0.292      0.770        -0.053     0.071
# ==============================================================================
# Omnibus:                       48.287   Durbin-Watson:                   0.949
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               49.801
# Skew:                           0.265   Prob(JB):                     1.53e-11
# Kurtosis:                       2.952   Cond. No.                     5.64e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.64e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Time to execute step 'nrh_estimate2': 1.02 s
# Total time to execute iteration 1 with iteration value None: 1.02 s

# %%
orca.run(["nrh_simulate2"])
# Out:
# Running step 'nrh_simulate2'
# count    75064.000000
# mean        16.332297
# std          2.698205
# min          1.578194
# 25%         14.478690
# 50%         16.253137
# 75%         17.872404
# max         51.174178
# dtype: float64
# Time to execute step 'nrh_simulate2': 2.38 s
# Total time to execute iteration 1 with iteration value None: 2.38 s

# %% [markdown]
# ## ELCM Estimation

# %%
orca.run(["elcm_estimate"])
# Out:
# Running step 'elcm_estimate'
# LCM RESULTS FOR SEGMENT 1
#
# Null Log-liklihood: -4605.170
# Log-liklihood at convergence: -1067.318
# Log-liklihood Ratio: 0.768
#
# +-----------------+-------------+------------+---------+
# | Component       | Coefficient | Std. Error | T-Score |
# +-----------------+-------------+------------+---------+
# | jobs_800m       |    0.156    |   0.026    |  6.016  |
# | ave_parcel_size |    1.308    |   0.039    |  33.157 |
# | is_office       |    1.752    |   0.308    |  5.680  |
# | is_retail       |    1.086    |   0.163    |  6.686  |
# | jobs1           |    1.770    |   0.038    |  46.998 |
# +-----------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 2
#
# Null Log-liklihood: -1082.215
# Log-liklihood at convergence: -49.372
# Log-liklihood Ratio: 0.954
#
# +-----------------+-------------+------------+---------+
# | Component       | Coefficient | Std. Error | T-Score |
# +-----------------+-------------+------------+---------+
# | jobs_800m       |    0.810    |   0.079    |  10.232 |
# | ave_parcel_size |    1.440    |   0.123    |  11.676 |
# | is_office       |    1.528    |   0.561    |  2.723  |
# | is_retail       |    2.211    |   0.574    |  3.849  |
# | jobs2           |    3.000    |   0.173    |  17.384 |
# +-----------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 3
#
# Null Log-liklihood: -4605.170
# Log-liklihood at convergence: -408.688
# Log-liklihood Ratio: 0.911
#
# +-----------------+-------------+------------+---------+
# | Component       | Coefficient | Std. Error | T-Score |
# +-----------------+-------------+------------+---------+
# | jobs_800m       |    0.233    |   0.035    |  6.720  |
# | ave_parcel_size |    1.311    |   0.094    |  13.886 |
# | is_office       |    1.299    |   0.238    |  5.449  |
# | is_retail       |    0.675    |   0.205    |  3.291  |
# | jobs3           |    1.692    |   0.050    |  33.557 |
# +-----------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 4
#
# Null Log-liklihood: -4605.170
# Log-liklihood at convergence: -1912.834
# Log-liklihood Ratio: 0.585
#
# +-----------------+-------------+------------+---------+
# | Component       | Coefficient | Std. Error | T-Score |
# +-----------------+-------------+------------+---------+
# | jobs_800m       |    0.048    |   0.033    |  1.434  |
# | ave_parcel_size |    1.138    |   0.042    |  27.367 |
# | is_office       |    1.589    |   0.146    |  10.886 |
# | is_retail       |    1.145    |   0.088    |  12.990 |
# | jobs4           |    1.312    |   0.041    |  31.698 |
# +-----------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 5
#
# Null Log-liklihood: -4605.170
# Log-liklihood at convergence: -1186.107
# Log-liklihood Ratio: 0.742
#
# +-----------------+-------------+------------+---------+
# | Component       | Coefficient | Std. Error | T-Score |
# +-----------------+-------------+------------+---------+
# | jobs_800m       |    0.198    |   0.045    |  4.414  |
# | ave_parcel_size |    0.981    |   0.054    |  18.037 |
# | is_office       |    0.651    |   0.160    |  4.079  |
# | is_retail       |    0.243    |   0.164    |  1.483  |
# | jobs5           |    1.191    |   0.051    |  23.489 |
# +-----------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 6
#
# Null Log-liklihood: -4605.170
# Log-liklihood at convergence: -1609.040
# Log-liklihood Ratio: 0.651
#
# +-----------------+-------------+------------+---------+
# | Component       | Coefficient | Std. Error | T-Score |
# +-----------------+-------------+------------+---------+
# | jobs_800m       |    0.128    |   0.036    |  3.526  |
# | ave_parcel_size |    1.142    |   0.047    |  24.244 |
# | is_office       |    0.981    |   0.134    |  7.315  |
# | is_retail       |    0.626    |   0.112    |  5.598  |
# | jobs6           |    1.299    |   0.048    |  26.884 |
# +-----------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 7
#
# Null Log-liklihood: -4605.170
# Log-liklihood at convergence: -1868.328
# Log-liklihood Ratio: 0.594
#
# +-----------------+-------------+------------+---------+
# | Component       | Coefficient | Std. Error | T-Score |
# +-----------------+-------------+------------+---------+
# | jobs_800m       |    0.279    |   0.043    |  6.493  |
# | ave_parcel_size |    1.179    |   0.048    |  24.454 |
# | is_office       |    1.695    |   0.145    |  11.716 |
# | is_retail       |    2.436    |   0.084    |  29.079 |
# | jobs7           |    0.889    |   0.053    |  16.831 |
# +-----------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 8
#
# Null Log-liklihood: -4605.170
# Log-liklihood at convergence: -1328.084
# Log-liklihood Ratio: 0.712
#
# +-----------------+-------------+------------+---------+
# | Component       | Coefficient | Std. Error | T-Score |
# +-----------------+-------------+------------+---------+
# | jobs_800m       |    0.218    |   0.029    |  7.463  |
# | ave_parcel_size |    1.368    |   0.048    |  28.728 |
# | is_office       |    0.335    |   0.182    |  1.837  |
# | is_retail       |    0.621    |   0.110    |  5.672  |
# | jobs8           |    1.345    |   0.042    |  31.719 |
# +-----------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 9
#
# Null Log-liklihood: -4605.170
# Log-liklihood at convergence: -1007.149
# Log-liklihood Ratio: 0.781
#
# +-----------------+-------------+------------+---------+
# | Component       | Coefficient | Std. Error | T-Score |
# +-----------------+-------------+------------+---------+
# | jobs_800m       |    0.294    |   0.034    |  8.660  |
# | ave_parcel_size |    1.321    |   0.050    |  26.514 |
# | is_office       |    1.526    |   0.129    |  11.845 |
# | is_retail       |    1.032    |   0.128    |  8.066  |
# | jobs9           |    1.225    |   0.046    |  26.551 |
# +-----------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 10
#
# Null Log-liklihood: -4605.170
# Log-liklihood at convergence: -1384.814
# Log-liklihood Ratio: 0.699
#
# +-----------------+-------------+------------+---------+
# | Component       | Coefficient | Std. Error | T-Score |
# +-----------------+-------------+------------+---------+
# | jobs_800m       |    0.186    |   0.034    |  5.422  |
# | ave_parcel_size |    1.367    |   0.067    |  20.542 |
# | is_office       |    2.183    |   0.113    |  19.385 |
# | is_retail       |    1.732    |   0.099    |  17.475 |
# | jobs10          |    1.054    |   0.047    |  22.287 |
# +-----------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 11
#
# Null Log-liklihood: -4605.170
# Log-liklihood at convergence: -1873.630
# Log-liklihood Ratio: 0.593
#
# +-----------------+-------------+------------+---------+
# | Component       | Coefficient | Std. Error | T-Score |
# +-----------------+-------------+------------+---------+
# | jobs_800m       |    0.121    |   0.031    |  3.895  |
# | ave_parcel_size |    1.240    |   0.048    |  25.908 |
# | is_office       |    1.798    |   0.108    |  16.723 |
# | is_retail       |    1.486    |   0.089    |  16.691 |
# | jobs11          |    1.268    |   0.048    |  26.616 |
# +-----------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 12
#
# Null Log-liklihood: -4605.170
# Log-liklihood at convergence: -1286.568
# Log-liklihood Ratio: 0.721
#
# +-----------------+-------------+------------+---------+
# | Component       | Coefficient | Std. Error | T-Score |
# +-----------------+-------------+------------+---------+
# | jobs_800m       |    0.308    |   0.045    |  6.792  |
# | ave_parcel_size |    1.199    |   0.034    |  34.937 |
# | is_office       |    1.592    |   0.112    |  14.272 |
# | is_retail       |    0.957    |   0.117    |  8.170  |
# | jobs12          |    0.952    |   0.053    |  17.855 |
# +-----------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 13
#
# Null Log-liklihood: -4605.170
# Log-liklihood at convergence: -669.819
# Log-liklihood Ratio: 0.855
#
# +-----------------+-------------+------------+---------+
# | Component       | Coefficient | Std. Error | T-Score |
# +-----------------+-------------+------------+---------+
# | jobs_800m       |    0.150    |   0.040    |  3.784  |
# | ave_parcel_size |    1.019    |   0.091    |  11.181 |
# | is_office       |    1.470    |   0.143    |  10.287 |
# | is_retail       |    0.985    |   0.160    |  6.173  |
# | jobs13          |    1.365    |   0.058    |  23.582 |
# +-----------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 14
#
# Null Log-liklihood: -4605.170
# Log-liklihood at convergence: -1652.882
# Log-liklihood Ratio: 0.641
#
# +-----------------+-------------+------------+---------+
# | Component       | Coefficient | Std. Error | T-Score |
# +-----------------+-------------+------------+---------+
# | jobs_800m       |    0.114    |   0.037    |  3.055  |
# | ave_parcel_size |    1.163    |   0.060    |  19.299 |
# | is_office       |    1.646    |   0.107    |  15.373 |
# | is_retail       |    1.249    |   0.095    |  13.145 |
# | jobs14          |    1.200    |   0.048    |  25.076 |
# +-----------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 15
#
# Null Log-liklihood: -4605.170
# Log-liklihood at convergence: -1879.921
# Log-liklihood Ratio: 0.592
#
# +-----------------+-------------+------------+---------+
# | Component       | Coefficient | Std. Error | T-Score |
# +-----------------+-------------+------------+---------+
# | jobs_800m       |    0.340    |   0.033    |  10.318 |
# | ave_parcel_size |    1.186    |   0.035    |  33.737 |
# | is_office       |    1.035    |   0.153    |  6.770  |
# | is_retail       |    0.174    |   0.130    |  1.335  |
# | jobs15          |    1.127    |   0.037    |  30.510 |
# +-----------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 16
#
# Null Log-liklihood: -4605.170
# Log-liklihood at convergence: -1763.612
# Log-liklihood Ratio: 0.617
#
# +-----------------+-------------+------------+---------+
# | Component       | Coefficient | Std. Error | T-Score |
# +-----------------+-------------+------------+---------+
# | jobs_800m       |    0.300    |   0.038    |  7.918  |
# | ave_parcel_size |    1.255    |   0.052    |  23.996 |
# | is_office       |    1.840    |   0.106    |  17.422 |
# | is_retail       |    1.036    |   0.101    |  10.250 |
# | jobs16          |    1.055    |   0.040    |  26.236 |
# +-----------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 17
#
# Null Log-liklihood: -4605.170
# Log-liklihood at convergence: -1231.850
# Log-liklihood Ratio: 0.733
#
# +-----------------+-------------+------------+---------+
# | Component       | Coefficient | Std. Error | T-Score |
# +-----------------+-------------+------------+---------+
# | jobs_800m       |    -0.045   |   0.029    |  -1.538 |
# | ave_parcel_size |    1.123    |   0.049    |  23.073 |
# | is_office       |    1.888    |   0.161    |  11.734 |
# | is_retail       |    1.641    |   0.115    |  14.255 |
# | jobs17          |    1.595    |   0.042    |  37.942 |
# +-----------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 18
#
# Null Log-liklihood: -4605.170
# Log-liklihood at convergence: -1885.552
# Log-liklihood Ratio: 0.591
#
# +-----------------+-------------+------------+---------+
# | Component       | Coefficient | Std. Error | T-Score |
# +-----------------+-------------+------------+---------+
# | jobs_800m       |    0.270    |   0.042    |  6.392  |
# | ave_parcel_size |    1.447    |   0.044    |  33.124 |
# | is_office       |    1.395    |   0.128    |  10.930 |
# | is_retail       |    1.991    |   0.080    |  24.998 |
# | jobs18          |    0.950    |   0.048    |  19.974 |
# +-----------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 19
#
# Null Log-liklihood: -4605.170
# Log-liklihood at convergence: -2681.514
# Log-liklihood Ratio: 0.418
#
# +-----------------+-------------+------------+---------+
# | Component       | Coefficient | Std. Error | T-Score |
# +-----------------+-------------+------------+---------+
# | jobs_800m       |    0.243    |   0.034    |  7.161  |
# | ave_parcel_size |    1.160    |   0.059    |  19.767 |
# | is_office       |    1.671    |   0.116    |  14.383 |
# | is_retail       |    1.834    |   0.076    |  24.040 |
# | jobs19          |    0.854    |   0.045    |  18.871 |
# +-----------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 20
#
# Null Log-liklihood: -4605.170
# Log-liklihood at convergence: -1191.118
# Log-liklihood Ratio: 0.741
#
# +-----------------+-------------+------------+---------+
# | Component       | Coefficient | Std. Error | T-Score |
# +-----------------+-------------+------------+---------+
# | jobs_800m       |    0.392    |   0.025    |  15.520 |
# | ave_parcel_size |    1.231    |   0.053    |  23.090 |
# | is_office       |    0.995    |   0.141    |  7.079  |
# | is_retail       |    0.392    |   0.116    |  3.374  |
# | jobs20          |    1.049    |   0.031    |  33.945 |
# +-----------------+-------------+------------+---------+
# Time to execute step 'elcm_estimate': 15.03 s
# Total time to execute iteration 1 with iteration value None: 15.03 s

# %%
orca.run(["jobs_transition", "elcm_simulate"])
# Out:
# Running step 'jobs_transition'
# 792871 agents before transition
# 800800 agents after transition
# Time to execute step 'jobs_transition': 0.30 s
# Running step 'elcm_simulate'
# There are 7314884 total available units
#     and 800800 total choosers
#     but there are 1 overfull buildings
#     for a total of 6522013 temporarily empty units
#     in 91152 buildings total in the region
# There are 7929 total movers for this LCM
# Assigned 7929 choosers to new units
# Total currently unplaced: 0
#     and there are now 6514084 empty units
#     and 0 overfull buildings
# Time to execute step 'elcm_simulate': 27.55 s
# Total time to execute iteration 1 with iteration value None: 27.85 s

# %% [markdown]
# ## HLCM Estimation

# %%
orca.run(["rsh_simulate"])
orca.run(["hlcm_estimate"])
# Out:
# Running step 'rsh_simulate'
# count    632386.000000
# mean        193.134270
# std          95.758474
# min           0.644238
# 25%         139.872706
# 50%         187.588360
# 75%         232.267315
# max        1160.735870
# dtype: float64
# Time to execute step 'rsh_simulate': 6.18 s
# Total time to execute iteration 1 with iteration value None: 6.18 s
# Running step 'hlcm_estimate'
# LCM RESULTS FOR SEGMENT 1
#
# Null Log-liklihood: -58680.345
# Log-liklihood at convergence: -41007.659
# Log-liklihood Ratio: 0.301
#
# +-----------------------------+-------------+------------+---------+
# | Component                   | Coefficient | Std. Error | T-Score |
# +-----------------------------+-------------+------------+---------+
# | np.log1p(sqft_per_unit)     |    0.062    |   0.007    |  8.944  |
# | year_built                  |    -0.001   |   0.000    |  -5.619 |
# | np.log1p(residential_units) |    1.248    |   0.008    | 164.589 |
# | jobs_800m                   |    0.031    |   0.005    |  5.783  |
# | residential_units_3000m     |    0.000    |   0.000    |  23.351 |
# | ave_income                  |    -0.185   |   0.019    |  -9.834 |
# +-----------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 2
#
# Null Log-liklihood: -58680.345
# Log-liklihood at convergence: -42910.173
# Log-liklihood Ratio: 0.269
#
# +-----------------------------+-------------+------------+---------+
# | Component                   | Coefficient | Std. Error | T-Score |
# +-----------------------------+-------------+------------+---------+
# | np.log1p(sqft_per_unit)     |    0.065    |   0.006    |  10.468 |
# | year_built                  |    -0.000   |   0.000    |  -0.324 |
# | np.log1p(residential_units) |    1.229    |   0.008    | 162.805 |
# | jobs_800m                   |    0.010    |   0.005    |  1.888  |
# | residential_units_3000m     |    0.000    |   0.000    |  10.748 |
# | ave_income                  |    -0.095   |   0.023    |  -4.080 |
# +-----------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 3
#
# Null Log-liklihood: -58680.345
# Log-liklihood at convergence: -44852.232
# Log-liklihood Ratio: 0.236
#
# +-----------------------------+-------------+------------+---------+
# | Component                   | Coefficient | Std. Error | T-Score |
# +-----------------------------+-------------+------------+---------+
# | np.log1p(sqft_per_unit)     |    0.058    |   0.006    |  9.233  |
# | year_built                  |    0.001    |   0.000    |  2.747  |
# | np.log1p(residential_units) |    1.217    |   0.008    | 159.044 |
# | jobs_800m                   |    -0.016   |   0.005    |  -3.031 |
# | residential_units_3000m     |    -0.000   |   0.000    |  -0.350 |
# | ave_income                  |    0.141    |   0.034    |  4.215  |
# +-----------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 4
#
# Null Log-liklihood: -58680.345
# Log-liklihood at convergence: -45113.161
# Log-liklihood Ratio: 0.231
#
# +-----------------------------+-------------+------------+---------+
# | Component                   | Coefficient | Std. Error | T-Score |
# +-----------------------------+-------------+------------+---------+
# | np.log1p(sqft_per_unit)     |    0.053    |   0.007    |  8.046  |
# | year_built                  |    0.000    |   0.000    |  0.748  |
# | np.log1p(residential_units) |    1.204    |   0.008    | 152.630 |
# | jobs_800m                   |    -0.017   |   0.005    |  -3.269 |
# | residential_units_3000m     |    0.000    |   0.000    |  1.848  |
# | ave_income                  |    1.469    |   0.036    |  40.958 |
# +-----------------------------+-------------+------------+---------+
# Time to execute step 'hlcm_estimate': 40.15 s
# Total time to execute iteration 1 with iteration value None: 40.16 s

# %%
orca.run(["households_transition_basic"], iter_vars = [2013])
orca.run(["hlcm_simulate"])
# Out:
# Running iteration 1 with iteration value 2013
# Running step 'households_transition_basic'
# 1034926 agents before transition
# 1045275 agents after transition
# Time to execute step 'households_transition_basic': 0.57 s
# Total time to execute iteration 1 with iteration value 2013: 0.57 s
# Running step 'hlcm_simulate'
# There are 1161992 total available units
#     and 1045275 total choosers
#     but there are 1 overfull buildings
#     for a total of 127066 temporarily empty units
#     in 77497 buildings total in the region
# There are 10349 total movers for this LCM
# Assigned 10349 choosers to new units
# Total currently unplaced: 0
#     and there are now 116717 empty units
#     and 0 overfull buildings
# Time to execute step 'hlcm_simulate': 3.62 s
# Total time to execute iteration 1 with iteration value None: 3.62 s
