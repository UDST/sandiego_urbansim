# %%
# %load_ext autoreload
# %autoreload 2
import models
import orca

# %%
# %%capture
orca.run(["build_networks", "neighborhood_vars"])

# %% [markdown]
# ## Residential Price Hedonice Estimation

# %%
orca.run(["rsh_estimate"])
# Out:
# Running step 'rsh_estimate'
# REGRESSION RESULTS FOR SEGMENT 19
#
#                                  OLS Regression Results
# ========================================================================================
# Dep. Variable:     np.log1p(res_price_per_sqft)   R-squared:                       0.235
# Model:                                      OLS   Adj. R-squared:                  0.234
# Method:                           Least Squares   F-statistic:                     824.2
# Date:                          Sun, 22 Nov 2015   Prob (F-statistic):               0.00
# Time:                                  23:45:34   Log-Likelihood:                -52275.
# No. Observations:                         45749   AIC:                         1.046e+05
# Df Residuals:                             45731   BIC:                         1.047e+05
# Df Model:                                    17
# Covariance Type:                      nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------------------------------
# Intercept                               -58.9924      1.796    -32.839      0.000       -62.513   -55.471
# I(year_built < 1940)[T.True]              0.8174      0.040     20.227      0.000         0.738     0.897
# I(distance_to_coast < 10000)[T.True]      0.3162      0.018     17.168      0.000         0.280     0.352
# I(distance_to_park < 400)[T.True]        -0.0009      0.016     -0.055      0.956        -0.032     0.030
# I(distance_to_school < 800)[T.True]       0.0926      0.013      7.248      0.000         0.068     0.118
# I(distance_to_freeway < 400)[T.True]     -0.0072      0.025     -0.284      0.776        -0.057     0.043
# year_built_1940to1950[T.True]             0.6134      0.032     19.045      0.000         0.550     0.677
# year_built_1950to1960[T.True]             0.5046      0.024     21.036      0.000         0.458     0.552
# year_built_1960to1970[T.True]             0.2723      0.020     13.379      0.000         0.232     0.312
# year_built_1970to1980[T.True]             0.1938      0.015     12.876      0.000         0.164     0.223
# I(ave_age_of_head_1500m < 35)[T.True]   -58.9924      1.796    -32.839      0.000       -62.513   -55.471
# ave_income                                0.2551      0.011     23.454      0.000         0.234     0.276
# jobs_400m                                -0.1102      0.003    -40.099      0.000        -0.116    -0.105
# res_occupancy_3000m                       3.1667      0.050     63.132      0.000         3.068     3.265
# np.log1p(distance_to_coast)              -0.1273      0.007    -18.515      0.000        -0.141    -0.114
# residential_units_1500m                3.248e-05   2.43e-06     13.392      0.000      2.77e-05  3.72e-05
# ave_children_1500m                       -0.6362      0.015    -42.201      0.000        -0.666    -0.607
# year_built                                0.0038      0.001      7.227      0.000         0.003     0.005
# ave_year_built_1500m                     14.6792      0.489     29.995      0.000        13.720    15.638
# ==============================================================================
# Omnibus:                    24775.003   Durbin-Watson:                   0.633
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           310139.882
# Skew:                          -2.344   Prob(JB):                         0.00
# Kurtosis:                      14.863   Cond. No.                     2.35e+19
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.81e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# REGRESSION RESULTS FOR SEGMENT 20
#
#                                  OLS Regression Results
# ========================================================================================
# Dep. Variable:     np.log1p(res_price_per_sqft)   R-squared:                       0.254
# Model:                                      OLS   Adj. R-squared:                  0.252
# Method:                           Least Squares   F-statistic:                     118.7
# Date:                          Sun, 22 Nov 2015   Prob (F-statistic):               0.00
# Time:                                  23:45:34   Log-Likelihood:                -11740.
# No. Observations:                          6980   AIC:                         2.352e+04
# Df Residuals:                              6959   BIC:                         2.367e+04
# Df Model:                                    20
# Covariance Type:                      nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------------------------------
# Intercept                               -80.0659     30.890     -2.592      0.010      -140.620   -19.512
# I(year_built < 1940)[T.True]              0.9892      0.304      3.251      0.001         0.393     1.586
# I(distance_to_coast < 10000)[T.True]      0.2009      0.063      3.215      0.001         0.078     0.323
# I(distance_to_park < 400)[T.True]         0.2742      0.064      4.312      0.000         0.150     0.399
# I(distance_to_school < 800)[T.True]       0.0451      0.051      0.888      0.374        -0.054     0.145
# year_built_1940to1950[T.True]             1.1169      0.237      4.708      0.000         0.652     1.582
# year_built_1950to1960[T.True]             1.0439      0.193      5.398      0.000         0.665     1.423
# year_built_1960to1970[T.True]             0.8076      0.163      4.941      0.000         0.487     1.128
# year_built_1970to1980[T.True]             0.4382      0.112      3.908      0.000         0.218     0.658
# year_built_1980to1990[T.True]             0.2070      0.078      2.670      0.008         0.055     0.359
# I(ave_age_of_head_1500m < 35)[T.True]   -80.0659     30.890     -2.592      0.010      -140.620   -19.512
# I(distance_to_freeway < 800)[T.True]     -0.3133      0.065     -4.795      0.000        -0.441    -0.185
# ave_income                               -0.1111      0.075     -1.476      0.140        -0.259     0.036
# jobs_400m                                -0.1170      0.010    -11.745      0.000        -0.137    -0.098
# res_occupancy_3000m                       3.0898      0.238     12.955      0.000         2.622     3.557
# np.log1p(distance_to_coast)              -0.3534      0.025    -14.403      0.000        -0.401    -0.305
# residential_units_1500m                8.851e-05   7.84e-06     11.287      0.000      7.31e-05     0.000
# ave_children_1500m                        0.0125      0.071      0.176      0.860        -0.127     0.152
# np.log1p(year_built)                     10.8222      7.866      1.376      0.169        -4.597    26.241
# ave_year_built_1500m                     11.4185      1.219      9.367      0.000         9.029    13.808
# np.log1p(distance_to_onramp)             -0.1126      0.021     -5.291      0.000        -0.154    -0.071
# np.log1p(distance_to_transit)            -0.2268      0.029     -7.874      0.000        -0.283    -0.170
# ==============================================================================
# Omnibus:                      428.304   Durbin-Watson:                   0.721
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              511.418
# Skew:                          -0.663   Prob(JB):                    8.85e-112
# Kurtosis:                       2.955   Cond. No.                     3.36e+19
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.12e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# REGRESSION RESULTS FOR SEGMENT 21
#
#                                  OLS Regression Results
# ========================================================================================
# Dep. Variable:     np.log1p(res_price_per_sqft)   R-squared:                       0.262
# Model:                                      OLS   Adj. R-squared:                  0.260
# Method:                           Least Squares   F-statistic:                     163.0
# Date:                          Sun, 22 Nov 2015   Prob (F-statistic):               0.00
# Time:                                  23:45:34   Log-Likelihood:                -11443.
# No. Observations:                          6443   AIC:                         2.292e+04
# Df Residuals:                              6428   BIC:                         2.302e+04
# Df Model:                                    14
# Covariance Type:                      nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------------------------------
# Intercept                              -175.6543     13.814    -12.716      0.000      -202.734  -148.575
# I(year_built < 1940)[T.True]              3.0768      0.194     15.886      0.000         2.697     3.457
# I(distance_to_school < 800)[T.True]      -0.4530      0.078     -5.789      0.000        -0.606    -0.300
# year_built_1940to1950[T.True]             3.1966      0.216     14.807      0.000         2.773     3.620
# year_built_1950to1960[T.True]             2.0664      0.131     15.816      0.000         1.810     2.323
# year_built_1960to1970[T.True]             1.6883      0.087     19.399      0.000         1.518     1.859
# I(ave_age_of_head_1500m < 35)[T.True]  -175.6543     13.814    -12.716      0.000      -202.734  -148.575
# ave_income                                0.4125      0.084      4.904      0.000         0.248     0.577
# jobs_3000m                            -3.174e-05   2.76e-06    -11.484      0.000     -3.72e-05 -2.63e-05
# res_occupancy_3000m                       1.0436      0.155      6.730      0.000         0.740     1.348
# residential_units_1500m                7.942e-05    6.4e-06     12.402      0.000      6.69e-05   9.2e-05
# np.log1p(year_built)                     47.0256      3.649     12.887      0.000        39.872    54.179
# np.log1p(distance_to_onramp)             -0.1045      0.019     -5.438      0.000        -0.142    -0.067
# np.log1p(distance_to_transit)            -0.3056      0.028    -10.881      0.000        -0.361    -0.251
# np.log1p(distance_to_school)             -0.3153      0.047     -6.744      0.000        -0.407    -0.224
# np.log1p(distance_to_coast)              -0.2964      0.014    -21.052      0.000        -0.324    -0.269
# ==============================================================================
# Omnibus:                      354.500   Durbin-Watson:                   0.854
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              436.822
# Skew:                           0.556   Prob(JB):                     1.40e-95
# Kurtosis:                       3.624   Cond. No.                     6.09e+20
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.68e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# Time to execute step 'rsh_estimate': 2.86 s
# Total time to execute iteration 1 with iteration value None: 2.86 s

# %%
orca.run(["rsh_simulate"])
# Out:
# Running step 'rsh_simulate'
# count    632386.000000
# mean        193.134270
# std          95.758474
# min           0.644238
# 25%         139.872706
# 50%         187.588360
# 75%         232.267315
# max        1160.735870
# dtype: float64
# Time to execute step 'rsh_simulate': 6.36 s
# Total time to execute iteration 1 with iteration value None: 6.36 s

# %% [markdown]
# ## Non-residential Rent Hedonic Estimation

# %%
orca.run(["nrh_estimate"])
# Out:
# Running step 'nrh_estimate'
# REGRESSION RESULTS FOR SEGMENT 2
#
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     np.log1p(nonres_rent_per_sqft)   R-squared:                       0.186
# Model:                                        OLS   Adj. R-squared:                  0.182
# Method:                             Least Squares   F-statistic:                     51.81
# Date:                            Sat, 21 Nov 2015   Prob (F-statistic):           7.17e-76
# Time:                                    22:26:53   Log-Likelihood:                -279.05
# No. Observations:                            1822   AIC:                             576.1
# Df Residuals:                                1813   BIC:                             625.7
# Df Model:                                       8
# Covariance Type:                        nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------------
# Intercept                       -0.4539      1.440     -0.315      0.753        -3.278     2.370
# I(year_built < 1940)[T.True]     0.6407      0.287      2.234      0.026         0.078     1.203
# I(year_built > 2005)[T.True]     0.1179      0.031      3.765      0.000         0.056     0.179
# np.log1p(stories)                0.4648      0.042     11.185      0.000         0.383     0.546
# jobs_400m                        0.0440      0.006      6.888      0.000         0.031     0.057
# year_built                       0.0013      0.001      1.736      0.083        -0.000     0.003
# distance_to_coast            -4.156e-06   4.45e-07     -9.342      0.000     -5.03e-06 -3.28e-06
# distance_to_freeway          -1.362e-05   2.03e-06     -6.702      0.000     -1.76e-05 -9.63e-06
# nonres_occupancy_3000m           0.0065      0.003      2.552      0.011         0.002     0.012
# ==============================================================================
# Omnibus:                      403.936   Durbin-Watson:                   1.158
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1879.207
# Skew:                           0.977   Prob(JB):                         0.00
# Kurtosis:                       7.575   Cond. No.                     7.26e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.26e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# REGRESSION RESULTS FOR SEGMENT 4
#
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     np.log1p(nonres_rent_per_sqft)   R-squared:                       0.227
# Model:                                        OLS   Adj. R-squared:                  0.221
# Method:                             Least Squares   F-statistic:                     37.83
# Date:                            Sat, 21 Nov 2015   Prob (F-statistic):           6.72e-53
# Time:                                    22:26:53   Log-Likelihood:                -242.66
# No. Observations:                            1038   AIC:                             503.3
# Df Residuals:                                1029   BIC:                             547.8
# Df Model:                                       8
# Covariance Type:                        nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------------
# Intercept                      -13.0926      1.777     -7.370      0.000       -16.579    -9.607
# I(year_built < 1940)[T.True]     0.2002      0.136      1.473      0.141        -0.067     0.467
# I(year_built > 2005)[T.True]     0.1365      0.049      2.782      0.006         0.040     0.233
# np.log1p(stories)                0.0976      0.023      4.290      0.000         0.053     0.142
# ave_income                       0.0046      0.003      1.325      0.186        -0.002     0.011
# jobs_400m                        0.0131      0.008      1.577      0.115        -0.003     0.029
# year_built                       0.0081      0.001      9.046      0.000         0.006     0.010
# distance_to_coast            -5.965e-06   5.76e-07    -10.363      0.000     -7.09e-06 -4.84e-06
# nonres_occupancy_3000m          -0.0151      0.005     -2.775      0.006        -0.026    -0.004
# ==============================================================================
# Omnibus:                       44.376   Durbin-Watson:                   1.409
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               90.746
# Skew:                          -0.269   Prob(JB):                     1.97e-20
# Kurtosis:                       4.345   Cond. No.                     5.20e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.2e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# REGRESSION RESULTS FOR SEGMENT 5
#
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     np.log1p(nonres_rent_per_sqft)   R-squared:                       0.152
# Model:                                        OLS   Adj. R-squared:                  0.148
# Method:                             Least Squares   F-statistic:                     34.71
# Date:                            Sat, 21 Nov 2015   Prob (F-statistic):           9.98e-45
# Time:                                    22:26:53   Log-Likelihood:                -550.98
# No. Observations:                            1359   AIC:                             1118.
# Df Residuals:                                1351   BIC:                             1160.
# Df Model:                                       7
# Covariance Type:                        nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------------
# Intercept                       -4.0303      1.485     -2.714      0.007        -6.943    -1.117
# I(year_built < 1940)[T.True]     0.1241      0.072      1.734      0.083        -0.016     0.264
# I(year_built > 2005)[T.True]     0.2302      0.065      3.559      0.000         0.103     0.357
# ave_income                       0.0513      0.006      8.077      0.000         0.039     0.064
# jobs_1500m                       0.0468      0.010      4.698      0.000         0.027     0.066
# year_built                       0.0031      0.001      4.192      0.000         0.002     0.005
# distance_to_coast            -4.954e-06   5.71e-07     -8.681      0.000     -6.07e-06 -3.83e-06
# nonres_occupancy_3000m           0.0395      0.016      2.469      0.014         0.008     0.071
# ==============================================================================
# Omnibus:                       10.174   Durbin-Watson:                   1.175
# Prob(Omnibus):                  0.006   Jarque-Bera (JB):               11.173
# Skew:                          -0.152   Prob(JB):                      0.00375
# Kurtosis:                       3.324   Cond. No.                     4.87e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.87e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Time to execute step 'nrh_estimate': 1.89 s
# Total time to execute iteration 1 with iteration value None: 1.89 s

# %%
orca.run(["nrh_simulate"])
# Out:
# Running step 'nrh_simulate'
# count    27077.000000
# mean        17.581523
# std          4.878404
# min          1.967944
# 25%         12.781416
# 50%         18.231857
# 75%         21.243186
# max         40.030645
# dtype: float64
# Time to execute step 'nrh_simulate': 3.81 s
# Total time to execute iteration 1 with iteration value None: 3.81 s

# %%
orca.run(["nrh_estimate2"])
# Out:
# Running step 'nrh_estimate2'
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     np.log1p(nonres_rent_per_sqft)   R-squared:                       0.195
# Model:                                        OLS   Adj. R-squared:                  0.193
# Method:                             Least Squares   F-statistic:                     113.4
# Date:                            Sat, 21 Nov 2015   Prob (F-statistic):          4.33e-191
# Time:                                    22:26:58   Log-Likelihood:                -2071.4
# No. Observations:                            4219   AIC:                             4163.
# Df Residuals:                                4209   BIC:                             4226.
# Df Model:                                       9
# Covariance Type:                        nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------------
# Intercept                       -0.6336      1.082     -0.585      0.558        -2.756     1.488
# I(year_built < 1940)[T.True]     0.1833      0.066      2.783      0.005         0.054     0.312
# I(year_built > 2005)[T.True]     0.1235      0.031      3.942      0.000         0.062     0.185
# np.log1p(stories)                0.3252      0.021     15.508      0.000         0.284     0.366
# ave_income                       0.0172      0.002      9.466      0.000         0.014     0.021
# jobs_400m                        0.0191      0.006      3.464      0.001         0.008     0.030
# year_built                       0.0016      0.001      2.854      0.004         0.000     0.003
# distance_to_coast            -6.337e-06   3.63e-07    -17.456      0.000     -7.05e-06 -5.63e-06
# distance_to_freeway          -3.227e-06   1.83e-06     -1.762      0.078     -6.82e-06  3.64e-07
# nonres_occupancy_3000m          -0.0235      0.003     -7.985      0.000        -0.029    -0.018
# ==============================================================================
# Omnibus:                       32.995   Durbin-Watson:                   0.958
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               33.590
# Skew:                           0.218   Prob(JB):                     5.08e-08
# Kurtosis:                       3.035   Cond. No.                     5.66e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.66e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Time to execute step 'nrh_estimate2': 1.18 s
# Total time to execute iteration 1 with iteration value None: 1.19 s

# %%
orca.run(["nrh_simulate2"])
# Out:
# Running step 'nrh_simulate2'
# count    75064.000000
# mean        16.738170
# std          2.720474
# min          0.649546
# 25%         15.021613
# 50%         16.662031
# 75%         18.233052
# max         54.207770
# dtype: float64
# Time to execute step 'nrh_simulate2': 2.47 s
# Total time to execute iteration 1 with iteration value None: 2.47 s

# %% [markdown]
# ## ELCM Estimation

# %%
orca.run(["elcm_estimate"])
# Out:
# Running step 'elcm_estimate'
# LCM RESULTS FOR SEGMENT 1
#
# Null Log-liklihood: -4605.170
# Log-liklihood at convergence: -1079.615
# Log-liklihood Ratio: 0.766
#
# +-----------------+-------------+------------+---------+
# | Component       | Coefficient | Std. Error | T-Score |
# +-----------------+-------------+------------+---------+
# | jobs_800m       |    0.128    |   0.027    |  4.823  |
# | ave_parcel_size |    1.276    |   0.032    |  40.244 |
# | is_office       |    2.109    |   0.300    |  7.038  |
# | is_retail       |    1.392    |   0.162    |  8.575  |
# | jobs1           |    1.798    |   0.038    |  47.107 |
# +-----------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 2
#
# Null Log-liklihood: -1082.215
# Log-liklihood at convergence: -44.388
# Log-liklihood Ratio: 0.959
#
# +-----------------+-------------+------------+---------+
# | Component       | Coefficient | Std. Error | T-Score |
# +-----------------+-------------+------------+---------+
# | jobs_800m       |    0.569    |   0.102    |  5.591  |
# | ave_parcel_size |    1.282    |   0.231    |  5.556  |
# | is_office       |    2.365    |   1.044    |  2.266  |
# | is_retail       |    1.243    |   0.542    |  2.292  |
# | jobs2           |    3.000    |   0.234    |  12.814 |
# +-----------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 3
#
# Null Log-liklihood: -4605.170
# Log-liklihood at convergence: -462.474
# Log-liklihood Ratio: 0.900
#
# +-----------------+-------------+------------+---------+
# | Component       | Coefficient | Std. Error | T-Score |
# +-----------------+-------------+------------+---------+
# | jobs_800m       |    0.167    |   0.035    |  4.779  |
# | ave_parcel_size |    1.179    |   0.069    |  17.133 |
# | is_office       |    1.446    |   0.227    |  6.372  |
# | is_retail       |    0.967    |   0.186    |  5.194  |
# | jobs3           |    1.606    |   0.052    |  31.012 |
# +-----------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 4
#
# Null Log-liklihood: -4605.170
# Log-liklihood at convergence: -1822.407
# Log-liklihood Ratio: 0.604
#
# +-----------------+-------------+------------+---------+
# | Component       | Coefficient | Std. Error | T-Score |
# +-----------------+-------------+------------+---------+
# | jobs_800m       |    0.054    |   0.035    |  1.547  |
# | ave_parcel_size |    1.250    |   0.046    |  27.080 |
# | is_office       |    1.462    |   0.143    |  10.250 |
# | is_retail       |    1.087    |   0.094    |  11.563 |
# | jobs4           |    1.334    |   0.043    |  30.844 |
# +-----------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 5
#
# Null Log-liklihood: -4605.170
# Log-liklihood at convergence: -1126.700
# Log-liklihood Ratio: 0.755
#
# +-----------------+-------------+------------+---------+
# | Component       | Coefficient | Std. Error | T-Score |
# +-----------------+-------------+------------+---------+
# | jobs_800m       |    0.266    |   0.044    |  6.017  |
# | ave_parcel_size |    1.104    |   0.059    |  18.695 |
# | is_office       |    0.960    |   0.158    |  6.086  |
# | is_retail       |    0.186    |   0.155    |  1.201  |
# | jobs5           |    1.186    |   0.051    |  23.405 |
# +-----------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 6
#
# Null Log-liklihood: -4605.170
# Log-liklihood at convergence: -1575.218
# Log-liklihood Ratio: 0.658
#
# +-----------------+-------------+------------+---------+
# | Component       | Coefficient | Std. Error | T-Score |
# +-----------------+-------------+------------+---------+
# | jobs_800m       |    0.092    |   0.035    |  2.619  |
# | ave_parcel_size |    1.208    |   0.041    |  29.480 |
# | is_office       |    1.143    |   0.133    |  8.612  |
# | is_retail       |    0.864    |   0.108    |  8.012  |
# | jobs6           |    1.345    |   0.047    |  28.539 |
# +-----------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 7
#
# Null Log-liklihood: -4605.170
# Log-liklihood at convergence: -1845.000
# Log-liklihood Ratio: 0.599
#
# +-----------------+-------------+------------+---------+
# | Component       | Coefficient | Std. Error | T-Score |
# +-----------------+-------------+------------+---------+
# | jobs_800m       |    0.367    |   0.040    |  9.096  |
# | ave_parcel_size |    1.282    |   0.049    |  26.067 |
# | is_office       |    1.796    |   0.150    |  11.978 |
# | is_retail       |    2.461    |   0.085    |  29.014 |
# | jobs7           |    0.790    |   0.050    |  15.722 |
# +-----------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 8
#
# Null Log-liklihood: -4605.170
# Log-liklihood at convergence: -1320.689
# Log-liklihood Ratio: 0.713
#
# +-----------------+-------------+------------+---------+
# | Component       | Coefficient | Std. Error | T-Score |
# +-----------------+-------------+------------+---------+
# | jobs_800m       |    0.181    |   0.028    |  6.432  |
# | ave_parcel_size |    1.269    |   0.041    |  30.960 |
# | is_office       |    0.700    |   0.168    |  4.163  |
# | is_retail       |    0.569    |   0.111    |  5.132  |
# | jobs8           |    1.390    |   0.040    |  34.348 |
# +-----------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 9
#
# Null Log-liklihood: -4605.170
# Log-liklihood at convergence: -1079.685
# Log-liklihood Ratio: 0.766
#
# +-----------------+-------------+------------+---------+
# | Component       | Coefficient | Std. Error | T-Score |
# +-----------------+-------------+------------+---------+
# | jobs_800m       |    0.264    |   0.033    |  7.957  |
# | ave_parcel_size |    1.200    |   0.044    |  27.061 |
# | is_office       |    1.671    |   0.124    |  13.486 |
# | is_retail       |    1.039    |   0.120    |  8.690  |
# | jobs9           |    1.178    |   0.045    |  26.157 |
# +-----------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 10
#
# Null Log-liklihood: -4605.170
# Log-liklihood at convergence: -1323.175
# Log-liklihood Ratio: 0.713
#
# +-----------------+-------------+------------+---------+
# | Component       | Coefficient | Std. Error | T-Score |
# +-----------------+-------------+------------+---------+
# | jobs_800m       |    0.199    |   0.034    |  5.772  |
# | ave_parcel_size |    1.276    |   0.056    |  22.606 |
# | is_office       |    2.633    |   0.114    |  23.098 |
# | is_retail       |    1.948    |   0.100    |  19.483 |
# | jobs10          |    1.068    |   0.049    |  21.966 |
# +-----------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 11
#
# Null Log-liklihood: -4605.170
# Log-liklihood at convergence: -1907.584
# Log-liklihood Ratio: 0.586
#
# +-----------------+-------------+------------+---------+
# | Component       | Coefficient | Std. Error | T-Score |
# +-----------------+-------------+------------+---------+
# | jobs_800m       |    0.191    |   0.030    |  6.335  |
# | ave_parcel_size |    1.275    |   0.060    |  21.113 |
# | is_office       |    2.002    |   0.103    |  19.451 |
# | is_retail       |    1.615    |   0.089    |  18.219 |
# | jobs11          |    1.088    |   0.045    |  23.925 |
# +-----------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 12
#
# Null Log-liklihood: -4605.170
# Log-liklihood at convergence: -1335.701
# Log-liklihood Ratio: 0.710
#
# +-----------------+-------------+------------+---------+
# | Component       | Coefficient | Std. Error | T-Score |
# +-----------------+-------------+------------+---------+
# | jobs_800m       |    0.384    |   0.039    |  9.829  |
# | ave_parcel_size |    1.257    |   0.039    |  32.232 |
# | is_office       |    1.952    |   0.112    |  17.368 |
# | is_retail       |    0.998    |   0.110    |  9.111  |
# | jobs12          |    0.808    |   0.047    |  17.084 |
# +-----------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 13
#
# Null Log-liklihood: -4605.170
# Log-liklihood at convergence: -619.004
# Log-liklihood Ratio: 0.866
#
# +-----------------+-------------+------------+---------+
# | Component       | Coefficient | Std. Error | T-Score |
# +-----------------+-------------+------------+---------+
# | jobs_800m       |    0.247    |   0.036    |  6.830  |
# | ave_parcel_size |    0.973    |   0.059    |  16.460 |
# | is_office       |    1.385    |   0.171    |  8.097  |
# | is_retail       |    0.799    |   0.160    |  4.995  |
# | jobs13          |    1.364    |   0.053    |  25.804 |
# +-----------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 14
#
# Null Log-liklihood: -4605.170
# Log-liklihood at convergence: -1719.948
# Log-liklihood Ratio: 0.627
#
# +-----------------+-------------+------------+---------+
# | Component       | Coefficient | Std. Error | T-Score |
# +-----------------+-------------+------------+---------+
# | jobs_800m       |    0.142    |   0.035    |  4.123  |
# | ave_parcel_size |    1.204    |   0.056    |  21.510 |
# | is_office       |    1.471    |   0.108    |  13.687 |
# | is_retail       |    1.066    |   0.097    |  11.039 |
# | jobs14          |    1.145    |   0.045    |  25.352 |
# +-----------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 15
#
# Null Log-liklihood: -4605.170
# Log-liklihood at convergence: -1954.505
# Log-liklihood Ratio: 0.576
#
# +-----------------+-------------+------------+---------+
# | Component       | Coefficient | Std. Error | T-Score |
# +-----------------+-------------+------------+---------+
# | jobs_800m       |    0.249    |   0.032    |  7.755  |
# | ave_parcel_size |    1.372    |   0.040    |  34.165 |
# | is_office       |    1.176    |   0.143    |  8.236  |
# | is_retail       |    0.654    |   0.117    |  5.569  |
# | jobs15          |    1.134    |   0.035    |  32.018 |
# +-----------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 16
#
# Null Log-liklihood: -4605.170
# Log-liklihood at convergence: -1692.679
# Log-liklihood Ratio: 0.632
#
# +-----------------+-------------+------------+---------+
# | Component       | Coefficient | Std. Error | T-Score |
# +-----------------+-------------+------------+---------+
# | jobs_800m       |    0.338    |   0.037    |  9.127  |
# | ave_parcel_size |    1.276    |   0.050    |  25.630 |
# | is_office       |    1.959    |   0.105    |  18.715 |
# | is_retail       |    1.006    |   0.105    |  9.612  |
# | jobs16          |    1.018    |   0.039    |  25.982 |
# +-----------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 17
#
# Null Log-liklihood: -4605.170
# Log-liklihood at convergence: -1267.415
# Log-liklihood Ratio: 0.725
#
# +-----------------+-------------+------------+---------+
# | Component       | Coefficient | Std. Error | T-Score |
# +-----------------+-------------+------------+---------+
# | jobs_800m       |    -0.042   |   0.029    |  -1.466 |
# | ave_parcel_size |    1.269    |   0.045    |  28.010 |
# | is_office       |    1.692    |   0.156    |  10.814 |
# | is_retail       |    1.560    |   0.108    |  14.498 |
# | jobs17          |    1.628    |   0.043    |  37.970 |
# +-----------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 18
#
# Null Log-liklihood: -4605.170
# Log-liklihood at convergence: -1960.708
# Log-liklihood Ratio: 0.574
#
# +-----------------+-------------+------------+---------+
# | Component       | Coefficient | Std. Error | T-Score |
# +-----------------+-------------+------------+---------+
# | jobs_800m       |    0.272    |   0.042    |  6.440  |
# | ave_parcel_size |    1.359    |   0.041    |  33.192 |
# | is_office       |    1.702    |   0.123    |  13.872 |
# | is_retail       |    2.007    |   0.078    |  25.587 |
# | jobs18          |    0.893    |   0.048    |  18.435 |
# +-----------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 19
#
# Null Log-liklihood: -4605.170
# Log-liklihood at convergence: -2698.893
# Log-liklihood Ratio: 0.414
#
# +-----------------+-------------+------------+---------+
# | Component       | Coefficient | Std. Error | T-Score |
# +-----------------+-------------+------------+---------+
# | jobs_800m       |    0.282    |   0.031    |  9.052  |
# | ave_parcel_size |    1.174    |   0.051    |  22.865 |
# | is_office       |    1.680    |   0.110    |  15.226 |
# | is_retail       |    1.697    |   0.076    |  22.320 |
# | jobs19          |    0.812    |   0.042    |  19.216 |
# +-----------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 20
#
# Null Log-liklihood: -4605.170
# Log-liklihood at convergence: -1094.843
# Log-liklihood Ratio: 0.762
#
# +-----------------+-------------+------------+---------+
# | Component       | Coefficient | Std. Error | T-Score |
# +-----------------+-------------+------------+---------+
# | jobs_800m       |    0.438    |   0.025    |  17.439 |
# | ave_parcel_size |    1.297    |   0.048    |  27.248 |
# | is_office       |    0.913    |   0.138    |  6.613  |
# | is_retail       |    0.303    |   0.125    |  2.413  |
# | jobs20          |    1.085    |   0.032    |  34.149 |
# +-----------------+-------------+------------+---------+
# Time to execute step 'elcm_estimate': 14.39 s
# Total time to execute iteration 1 with iteration value None: 14.40 s

# %%
orca.run(["jobs_transition", "elcm_simulate"])
# Out:
# Running step 'jobs_transition'
# 792871 agents before transition
# 800800 agents after transition
# Time to execute step 'jobs_transition': 0.32 s
# Running step 'elcm_simulate'
# There are 989901 total available units
#     and 800800 total choosers
#     but there are 23348 overfull buildings
#     for a total of 634200 temporarily empty units
#     in 73376 buildings total in the region
# There are 7929 total movers for this LCM
# Assigned 7929 choosers to new units
# Total currently unplaced: 0
#     and there are now 189101 empty units
#     and 23347 overfull buildings
# Time to execute step 'elcm_simulate': 5.78 s
# Total time to execute iteration 1 with iteration value None: 6.10 s

# %% [markdown]
# ## HLCM Estimation

# %%
orca.run(["rsh_simulate"])
orca.run(["hlcm_estimate"])
# Out:
# Running step 'rsh_simulate'
# count    632386.000000
# mean        193.134270
# std          95.758474
# min           0.644238
# 25%         139.872706
# 50%         187.588360
# 75%         232.267315
# max        1160.735870
# dtype: float64
# Time to execute step 'rsh_simulate': 6.14 s
# Total time to execute iteration 1 with iteration value None: 6.14 s
# Running step 'hlcm_estimate'
# LCM RESULTS FOR SEGMENT 1
#
# Null Log-liklihood: -58680.345
# Log-liklihood at convergence: -40945.283
# Log-liklihood Ratio: 0.302
#
# +-----------------------------+-------------+------------+---------+
# | Component                   | Coefficient | Std. Error | T-Score |
# +-----------------------------+-------------+------------+---------+
# | np.log1p(sqft_per_unit)     |    0.048    |   0.007    |  7.313  |
# | year_built                  |    -0.001   |   0.000    |  -4.700 |
# | np.log1p(residential_units) |    1.250    |   0.008    | 165.011 |
# | jobs_800m                   |    0.033    |   0.005    |  6.225  |
# | residential_units_3000m     |    0.000    |   0.000    |  20.254 |
# | ave_income                  |    -0.166   |   0.021    |  -7.918 |
# +-----------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 2
#
# Null Log-liklihood: -58680.345
# Log-liklihood at convergence: -42716.613
# Log-liklihood Ratio: 0.272
#
# +-----------------------------+-------------+------------+---------+
# | Component                   | Coefficient | Std. Error | T-Score |
# +-----------------------------+-------------+------------+---------+
# | np.log1p(sqft_per_unit)     |    0.067    |   0.006    |  10.812 |
# | year_built                  |    0.000    |   0.000    |  1.891  |
# | np.log1p(residential_units) |    1.227    |   0.007    | 164.649 |
# | jobs_800m                   |    0.011    |   0.005    |  2.080  |
# | residential_units_3000m     |    0.000    |   0.000    |  11.983 |
# | ave_income                  |    -0.107   |   0.022    |  -4.798 |
# +-----------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 3
#
# Null Log-liklihood: -58680.345
# Log-liklihood at convergence: -44844.561
# Log-liklihood Ratio: 0.236
#
# +-----------------------------+-------------+------------+---------+
# | Component                   | Coefficient | Std. Error | T-Score |
# +-----------------------------+-------------+------------+---------+
# | np.log1p(sqft_per_unit)     |    0.057    |   0.006    |  9.114  |
# | year_built                  |    0.000    |   0.000    |  1.973  |
# | np.log1p(residential_units) |    1.202    |   0.008    | 158.596 |
# | jobs_800m                   |    -0.016   |   0.005    |  -3.000 |
# | residential_units_3000m     |    0.000    |   0.000    |  0.450  |
# | ave_income                  |    0.154    |   0.034    |  4.482  |
# +-----------------------------+-------------+------------+---------+
# LCM RESULTS FOR SEGMENT 4
#
# Null Log-liklihood: -58680.345
# Log-liklihood at convergence: -45209.735
# Log-liklihood Ratio: 0.230
#
# +-----------------------------+-------------+------------+---------+
# | Component                   | Coefficient | Std. Error | T-Score |
# +-----------------------------+-------------+------------+---------+
# | np.log1p(sqft_per_unit)     |    0.061    |   0.007    |  9.005  |
# | year_built                  |    0.000    |   0.000    |  0.964  |
# | np.log1p(residential_units) |    1.205    |   0.008    | 150.989 |
# | jobs_800m                   |    -0.005   |   0.005    |  -1.044 |
# | residential_units_3000m     |    0.000    |   0.000    |  2.546  |
# | ave_income                  |    1.531    |   0.035    |  43.296 |
# +-----------------------------+-------------+------------+---------+
# Time to execute step 'hlcm_estimate': 45.92 s
# Total time to execute iteration 1 with iteration value None: 45.92 s

# %%
orca.run(["households_transition_basic"], iter_vars = [2013])
orca.run(["hlcm_simulate"])
# Out:
# Running iteration 1 with iteration value 2013
# Running step 'households_transition_basic'
# 1034926 agents before transition
# 1045275 agents after transition
# Time to execute step 'households_transition_basic': 0.57 s
# Total time to execute iteration 1 with iteration value 2013: 0.58 s
# Running step 'hlcm_simulate'
# There are 1161992 total available units
#     and 1045275 total choosers
#     but there are 1 overfull buildings
#     for a total of 127066 temporarily empty units
#     in 77497 buildings total in the region
# There are 10349 total movers for this LCM
# Assigned 10349 choosers to new units
# Total currently unplaced: 0
#     and there are now 116717 empty units
#     and 0 overfull buildings
# Time to execute step 'hlcm_simulate': 3.57 s
# Total time to execute iteration 1 with iteration value None: 3.57 s
